# %% [markdown]
# # Understanding Delta Lake Transaction Log
# Undstand the cloud storage directory structure behind delta lake tables.

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS demo.delta_lake
  MANAGED LOCATION 'abfss://demo@deacourseextdl137.dfs.core.windows.net/delta_lake';

# %%
# %sql
CREATE TABLE IF NOT EXISTS demo.delta_lake.companies (
  company_name STRING,
  founded_date DATE,
  country STRING
);

# %%
# %sql
DESC EXTENDED demo.delta_lake.companies;

# %%
# %sql
INSERT INTO demo.delta_lake.companies VALUES ('Databricks', '2012-01-01', 'USA');

# %%
# %sql
SELECT * FROM demo.delta_lake.companies;

# %%
# %sql
INSERT INTO demo.delta_lake.companies VALUES
  ('Apple', '1976-04-01', 'USA'),
  ('Microsoft', '1975-04-01', 'USA'),
  ('Google', '1998-09-04', 'USA');
